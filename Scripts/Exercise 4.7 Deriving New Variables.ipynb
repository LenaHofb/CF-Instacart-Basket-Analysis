# %%
#Import Libraries
import pandas as pd
import numpy as np
import os

# %%
#Import Dataframes\n",
path=r'C:\\Users\\north\\08-2024 Instacart Basket Analysis'
ords_prods_merge= pd.read_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'ords_prods_merge.pkl'))

# %%
#Create Subset
df=ords_prods_merge[:1000000]

# %%
df.shape
# Out:
# (1000000, 16)

# %%
#Define a Function
def price_label(row):

  if row['prices'] <= 5:
    return 'Low-range product'
  elif (row['prices'] > 5) and (row['prices'] <= 15):
    return 'Mid-range product'
  elif row['prices'] > 15:
    return 'High range product'
  else: return 'Not enough data'

# %%
# Apply the function
df['price_range'] = df.apply(price_label, axis=1)
# Out:
# C:\Users\north\AppData\Local\Temp\ipykernel_20176\902492192.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['price_range'] = df.apply(price_label, axis=1)

# %%
df['price_range'].value_counts(dropna=False)
# Out:
# price_range
# Mid-range product     673183
# Low-range product     314392
# High range product     12425
# Name: count, dtype: int64

# %%
#Define Function on entire Dataframe"

# %%
df.loc[df['prices'] > 15, 'price_range_loc'] = 'High-range product'
# Out:
# C:\Users\north\AppData\Local\Temp\ipykernel_20176\1169838859.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[df['prices'] > 15, 'price_range_loc'] = 'High-range product'

# %%
df.loc[(df['prices'] <= 15) & (df['prices'] > 5), 'price_range_loc'] = 'Mid-range product'

# %%
df.loc[df['prices'] <= 5, 'price_range_loc'] = 'Low-range product'

# %%
#Apply Function
df['price_range_loc'].value_counts(dropna=False)
# Out:
# price_range_loc
# Mid-range product     673183
# Low-range product     314392
# High-range product     12425
# Name: count, dtype: int64

# %%
#Frequency counts 'order_weekday'
ords_prods_merge ['order_weekday'].value_counts(dropna=False)
# Out:
# order_weekday
# 0    6204182
# 1    5660230
# 6    4496490
# 2    4213830
# 5    4205791
# 3    3840534
# 4    3783802
# Name: count, dtype: int64

# %%
#Create for-loop 'busiest day'
result = []

for value in ords_prods_merge["order_weekday"]:
  if value == 0:
    result.append("Busiest day")
  elif value == 4:
    result.append("Least busy")
  else:
    result.append("Regularly busy")

# %%
result
# Out:
# ['Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
# ...

# %%
#Create new column 'result' in df ords_prods_merge
ords_prods_merge ['busiest_day']=result

# %%
#Frequency counts 'busiest_day'
ords_prods_merge ['busiest_day'].value_counts(dropna=False)
# Out:
# busiest_day
# Regularly busy    22416875
# Busiest day        6204182
# Least busy         3783802
# Name: count, dtype: int64

# %% [markdown]
# ##**Answers Exercise 4.7**

# %% [markdown]
# ##2. Change Labels to 'Busiest days', Create new column for two slowest days

# %%
#Modify the for-loop, ckd line 84 for frequency of order_weekday
result = []

for value in ords_prods_merge["order_weekday"]:
    if value in (0, 1):
        result.append("Busiest days")
    elif value in (3, 4):
        result.append("Slowest days")
    else:
        result.append("Regular days")

# %%
result
# Out:
# ['Regular days',
#  'Regular days',
#  'Regular days',
#  'Regular days',
#  'Regular days',
#  'Slowest days',
#  'Slowest days',
#  'Slowest days',
#  'Slowest days',
#  'Slowest days',
#  'Slowest days',
#  'Slowest days',
#  'Slowest days',
#  'Slowest days',
#  'Slowest days',
#  'Slowest days',
#  'Slowest days',
#  'Slowest days',
#  'Slowest days',
#  'Slowest days',
#  'Slowest days',
#  'Slowest days',
#  'Slowest days',
#  'Slowest days',
#  'Slowest days',
#  'Slowest days',
#  'Slowest days',
#  'Slowest days',
#  'Slowest days',
#  'Regular days',
#  'Regular days',
#  'Regular days',
#  'Regular days',
#  'Busiest days',
#  'Busiest days',
#  'Busiest days',
#  'Busiest days',
#  'Busiest days',
#  'Busiest days',
#  'Busiest days',
#  'Busiest days',
#  'Busiest days',
#  'Busiest days',
#  'Busiest days',
#  'Busiest days',
#  'Busiest days',
#  'Busiest days',
#  'Busiest days',
#  'Busiest days',
#  'Busiest days',
#  'Slowest days',
#  'Slowest days',
# ...

# %%
#Create new column 'busiest days' in df ords_prods_merge
ords_prods_merge ['busiest_days']=result

# %%
##3. Check Frequency of new column for accuracy
ords_prods_merge ['busiest_days'].value_counts(dropna=False)
# Out:
# busiest_days
# Regular days    12916111
# Busiest days    11864412
# Slowest days     7624336
# Name: count, dtype: int64

# %%
ords_prods_merge.columns
# Out:
# Index(['Unnamed: 0', 'order_id', 'user_id', 'order_number', 'order_weekday',
#        'order_hour_of_day', 'days_since_prior_order', 'first_order',
#        'product_id', 'add_to_cart_order', 'reordered', 'product_name',
#        'aisle_id', 'department_id', 'prices', 'merge_flag', 'busiest_days'],
#       dtype='object')

# %%
#Drop previous 'busiest_day'column
ords_prods_merge = ords_prods_merge.drop(columns=['busiest_day'])

# %%
ords_prods_merge.columns
# Out:
# Index(['Unnamed: 0', 'order_id', 'user_id', 'order_number', 'order_weekday',
#        'order_hour_of_day', 'days_since_prior_order', 'first_order',
#        'product_id', 'add_to_cart_order', 'reordered', 'product_name',
#        'aisle_id', 'department_id', 'prices', 'merge_flag', 'busiest_days'],
#       dtype='object')

# %% [markdown]
# #Answer to point 3.#
#
# **- Busiest Days Label**: Days labeled as "Busiest days" correspond to the actual two busiest days (identified by the highest order counts).
# **- Slowest Days Label**: Days labeled as "Slowest days" are indeed the two days with the lowest order counts.
# **- Regular Days Label**: As for all other counts I have created another label "Regular Day"
# The total count of entries matches the expected number.

# %%
#4. Identify the busiest hour of the day. Labeled \"Most orders\", \"Average orders\", \"Fewest orders\

# %%
#Frequency of 'order_hour_of_day'
ords_prods_merge['order_hour_of_day'].value_counts(dropna=False)
# Out:
# order_hour_of_day
# 10    2761760
# 11    2736140
# 14    2689136
# 15    2662144
# 13    2660954
# 12    2618532
# 16    2535202
# 9     2454203
# 17    2087654
# 8     1718118
# 18    1636502
# 19    1258305
# 20     976156
# 7      891054
# 21     795637
# 22     634225
# 23     402316
# 6      290493
# 0      218769
# 1      115700
# 5       87961
# 2       69375
# 4       53242
# 3       51281
# Name: count, dtype: int64

# %%
#Create for-loop 'busiest_period_of_day'
result = []

for value in ords_prods_merge["order_hour_of_day"]:
    if value == 10:
        result.append("Most orders")
    elif value == 3:
        result.append("Fewest orders")
    else:
        result.append("Average orders")

# %%
result
# Out:
# ['Average orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
#  'Average orders',
# ...

# %%
#Create new column 'busiest_period_of_day' in df ords_prods_merge
ords_prods_merge ['busiest_period_of_day']=result

# %%
#Frequency of new column 'busiest_period_of_day
ords_prods_merge['busiest_period_of_day'].value_counts(dropna=False)
# Out:
# busiest_period_of_day
# Average orders    29591818
# Most orders        2761760
# Fewest orders        51281
# Name: count, dtype: int64

# %%
#Export df as pickle file in 'Prepared Data'
ords_prods_merge.to_pickle(os.path.join(path, '02 Data','Prepared Data', 'orders_prods_merge_new clmns.pkl'))
